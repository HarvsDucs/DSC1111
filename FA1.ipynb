# %%
from IPython.display import Image
Image("tableau.png")

# %% [markdown]
# Reflection on Tableau Data Visualization Assignment
#
#
# This assignment provided valuable hands-on experience with Tableau's core functionality and demonstrated the power of interactive data visualization. Working with the Superstore dataset, I gained practical understanding of how to transform raw data into meaningful visual insights.
# One of the most important concepts I learned was the distinction between dimensions and measures in Tableau. Understanding that green fields represent categorical data for grouping while blue fields represent quantitative data for aggregation fundamentally changed how I approached building visualizations. This knowledge directly impacted the effectiveness of my charts.
# Creating the three different chart types—bar charts for categorical comparisons, line charts for trend analysis, and pie charts for proportional relationships—taught me that visualization choice should align with the story the data needs to tell. Each chart type serves a specific analytical purpose, and selecting the right one is crucial for clear communication.
# The dashboard creation process was particularly enlightening. Learning to combine multiple visualizations into a cohesive, interactive dashboard showed me how individual charts become more powerful when they work together. Adding filter actions and interactivity transformed static charts into dynamic exploration tools, allowing users to drill down into specific segments and discover insights through interaction.
# Perhaps most importantly, this assignment reinforced that effective data visualization isn't just about creating pretty charts—it's about enabling data-driven decision making. The interactive dashboard I created allows stakeholders to explore sales patterns across categories, regions, and time periods, providing actionable insights that would be difficult to discern from raw data alone.
# This foundation in Tableau will be invaluable for future data analysis projects.

# %% [markdown]
# tableau workbook link: https://public.tableau.com/app/profile/harvey.ducay/viz/Book1_17501300126640/Dashboard1?publish=yes
